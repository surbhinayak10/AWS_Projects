# %%
# Importing all the required libraries
import pandas as pd
import boto3
from io import StringIO

# %% [markdown]
# * **Loading Data into pandas**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/mushrooms.csv')
# Displaying first 5 rows of dataset
df.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# * **Creating Bucket in S3**

# %%
s3_client = boto3.client('s3')
s3_client.create_bucket(Bucket='iansurbhi')
# Out:
# {'ResponseMetadata': {'RequestId': '2DEN2GZ891SSKXPB',
#   'HostId': 'Jc2iCkvKvLiv0Fg0mQ+DnZ90qwnDTOPYf6X31+Lcg/nGA6X5+2UN/vLDHA5fMJLcgaDoLwXVU+0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Jc2iCkvKvLiv0Fg0mQ+DnZ90qwnDTOPYf6X31+Lcg/nGA6X5+2UN/vLDHA5fMJLcgaDoLwXVU+0=',
#    'x-amz-request-id': '2DEN2GZ891SSKXPB',
#    'date': 'Mon, 07 Mar 2022 03:31:46 GMT',
#    'location': '/iansurbhi',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': '/iansurbhi'}

# %% [markdown]
# * **Upload file to s3 bucket**

# %%
bucket = 'iansurbhi' # already created on S3
csv_buffer = StringIO()
df.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object(bucket, 'mushroom.csv').put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '1WVRF2XWQCTQJFJN',
#   'HostId': 'YYa3+Xpn5bm/7bZLGysALxPd0v4p7rc2y8GM2EfEE6hY3JaxqOGsMF0uis4frWBPvTzWU0H3wqY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'YYa3+Xpn5bm/7bZLGysALxPd0v4p7rc2y8GM2EfEE6hY3JaxqOGsMF0uis4frWBPvTzWU0H3wqY=',
#    'x-amz-request-id': '1WVRF2XWQCTQJFJN',
#    'date': 'Mon, 07 Mar 2022 03:43:01 GMT',
#    'etag': '"572d4ec2cb45b8a46658cdc2f43df949"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"572d4ec2cb45b8a46658cdc2f43df949"'}

# %% [markdown]
# * **Output a confirmation that file is on s3 bucket**

# %%
bucket = s3.Bucket('iansurbhi')

for obj in bucket.objects.all():
    key = obj.key
    body = obj.get()['Body'].read()
    print(key)
    print(body)
# Out:
# mushroom.csv
# ...

# %% [markdown]
# ### Reference:
#
# 1. https://stackoverflow.com/questions/38154040/save-dataframe-to-csv-directly-to-s3-python
# 2. https://stackoverflow.com/questions/36205481/read-file-content-from-s3-bucket-with-boto3
